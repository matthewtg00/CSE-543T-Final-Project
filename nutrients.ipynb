# %%
import pandas as pd

# %%
df = pd.read_csv('nutrients_csvfile_small.csv')

# %%
df = df.replace("t",0.0)
df = df.replace("a",0.0)
df = df.replace("t'",0.0)

# %%
"""
df["Grams"] = pd.to_numeric(df["Grams"])
df["Calories"] = pd.to_numeric(df["Calories"])
df["Protein"] = pd.to_numeric(df["Protein"])
df["Fat"] = pd.to_numeric(df["Fat"])
df["Sat.Fat"] = pd.to_numeric(df["Sat.Fat"])
df["Fiber"] = pd.to_numeric(df["Fiber"])
df["Carbs"] = pd.to_numeric(df["Carbs"])
"""
df["Grams"] = df["Grams"].astype(float)
df["Calories"] = df["Calories"].astype(float)
df["Protein"] = df["Protein"].astype(float)
df["Fat"] = df["Fat"].astype(float)
df["Sat.Fat"] = df["Sat.Fat"].astype(float)
df["Fiber"] = df["Fiber"].astype(float)
df["Carbs"] = df["Carbs"].astype(float)

# %%
df.dtypes
# Out:
# Food         object
# Measure      object
# Grams       float64
# Calories    float64
# Protein     float64
# Fat         float64
# Sat.Fat     float64
# Fiber       float64
# Carbs       float64
# Category     object
# dtype: object

# %%
df
# Out:
#                        Food    Measure  Grams  Calories  Protein   Fat  \
# 0                skim. milk      1 cup  250.0     128.0     18.0   4.0
# 1   Eggs Scrambled or fried          2  128.0     220.0     13.0  16.0
# 2                 Olive oil        1T.   14.0     125.0      0.0  14.0
# 3                     Steak      3 oz.   85.0     330.0     20.0  27.0
# 4                    Salmon      3 oz.   85.0     120.0     17.0   5.0
# 5                   Carrots      1 cup  150.0      45.0      1.0   0.0
# 6                   Lettuce   1/4 head  100.0      14.0      1.0   0.0
# 7               Apples, raw      1 med  130.0      70.0      0.0   0.0
# 8               Pumpkin Pie    1 slice  130.0     265.0      5.0  12.0
# 9                 Ice cream      1 cup  188.0     300.0      6.0  18.0
# 10                  chicken      3 oz.   85.0     185.0     23.0   9.0
# 11                   Shrimp      3 oz.   85.0     110.0     23.0   1.0
# 12                  Avocado  1/2 large  108.0     185.0      2.0  18.0
# 13             chicken soup      1 cup  250.0      75.0      4.0   2.0
# 14           Milk chocolate  2-oz. bar   56.0     290.0      2.0   6.0
# 15                Hamburger      3 oz.   85.0     245.0     21.0  17.0
# 16                    Bacon   2 slices   16.0      95.0      4.0   8.0
# 17               Roast beef      3 oz.   85.0     390.0     16.0  36.0
# 18                  Lobster      aver.  100.0      92.0     18.0   1.0
# 19                Asparagus   6 spears   96.0      18.0      1.0   0.0
# 20              Cauliflower      1 cup  120.0      30.0      3.0   0.0
# 21              Blueberries      1 cup  250.0     245.0      1.0   0.0
# 22                   Grapes      1 cup  153.0      70.0      1.0   0.0
# 23              Whole-wheat    1 slice   23.0      55.0      2.0   1.0
# 24               Cornflakes      1 cup   25.0     110.0      2.0   0.0
# 25                  Oatmeal      1 cup  236.0     150.0      5.0   3.0
# 26              Sponge cake    1 slice   40.0     115.0      3.0   2.0
# 27                Doughnuts          1   33.0     135.0      2.0   7.0
#
#     Sat.Fat  Fiber  Carbs                          Category
# 0       3.0   1.00   13.0                    Dairy products
# 1      14.0   0.00    1.0                    Dairy products
# 2       3.0   0.00    0.0           Fats, Oils, Shortenings
# 3      25.0   0.00    0.0                     Meat, Poultry
# 4       1.0   0.00    0.0                     Fish, Seafood
# 5       0.0   0.90   10.0                    Vegetables A-E
# 6       0.0   0.50    2.0                    Vegetables F-P
# 7       0.0   1.00   18.0                        Fruits A-F
# 8      11.0   8.00   34.0                  Desserts, sweets
# 9      16.0   0.00   29.0                    Dairy products
# 10      7.0   0.00    0.0                     Meat, Poultry
# 11      0.0   0.00    0.0                     Fish, Seafood
# 12     12.0   1.80    6.0                        Fruits A-F
# 13      2.0   0.00   10.0                             Soups
# 14      6.0   0.20   44.0                  Desserts, sweets
# 15     15.0   0.00    0.0                     Meat, Poultry
# 16      7.0   0.00    1.0                     Meat, Poultry
# 17     35.0   0.00    0.0                     Meat, Poultry
# 18      0.0   0.00    0.0                     Fish, Seafood
# 19      0.0   0.50    3.0                    Vegetables A-E
# 20      0.0   1.00    6.0                    Vegetables A-E
# 21      0.0   2.00   65.0                        Fruits A-F
# 22      0.0   0.80   16.0                        Fruits G-P
# 23      0.0   0.31   11.0  Breads, cereals, fastfood,grains
# 24      0.0   0.10   25.0  Breads, cereals, fastfood,grains
# 25      2.0   4.60   26.0  Breads, cereals, fastfood,grains
# 26      2.0   0.00   22.0                  Desserts, sweets
# 27      4.0   0.00   17.0                  Desserts, sweets

# %%
def taste_factor(row):
    if row['Category'] == 'Dairy products':
        return 0.3
    if row['Category'] == 'Fats, Oils, Shortenings':
        return 0.1
    if row['Category'] == 'Meat, Poultry':
        return 0.5
    if row['Category'] == 'Fish, Seafood':
        return 0.5
    if row['Category'] == 'Vegetables A-E':
        return 0.5
    if row['Category'] == 'Vegetables F-P':
        return 0.5
    if row['Category'] == 'Vegetables R-Z':
        return 0.5
    if row['Category'] == 'Fruits A-F':
        return 0.6
    if row['Category'] == 'Fruits G-P':
        return 0.6
    if row['Category'] == 'Fruits R-Z':
        return 0.6
    if row['Category'] == 'Breads, cereals, fastfood,grains':
        return 0.4
    if row['Category'] == 'Soups':
        return 0.5
    if row['Category'] == 'Desserts, sweets':
        return 0.2
    if row['Category'] == 'Jams, Jellies':
        return 0.2
    if row['Category'] == 'Drinks,Alcohol, Beverages':
        return 0.5

# %%
df['taste_factor'] = df.apply(taste_factor, axis=1)
df
# Out:
#                        Food    Measure  Grams  Calories  Protein   Fat  \
# 0                skim. milk      1 cup  250.0     128.0     18.0   4.0
# 1   Eggs Scrambled or fried          2  128.0     220.0     13.0  16.0
# 2                 Olive oil        1T.   14.0     125.0      0.0  14.0
# 3                     Steak      3 oz.   85.0     330.0     20.0  27.0
# 4                    Salmon      3 oz.   85.0     120.0     17.0   5.0
# 5                   Carrots      1 cup  150.0      45.0      1.0   0.0
# 6                   Lettuce   1/4 head  100.0      14.0      1.0   0.0
# 7               Apples, raw      1 med  130.0      70.0      0.0   0.0
# 8               Pumpkin Pie    1 slice  130.0     265.0      5.0  12.0
# 9                 Ice cream      1 cup  188.0     300.0      6.0  18.0
# 10                  chicken      3 oz.   85.0     185.0     23.0   9.0
# 11                   Shrimp      3 oz.   85.0     110.0     23.0   1.0
# 12                  Avocado  1/2 large  108.0     185.0      2.0  18.0
# 13             chicken soup      1 cup  250.0      75.0      4.0   2.0
# 14           Milk chocolate  2-oz. bar   56.0     290.0      2.0   6.0
# 15                Hamburger      3 oz.   85.0     245.0     21.0  17.0
# 16                    Bacon   2 slices   16.0      95.0      4.0   8.0
# 17               Roast beef      3 oz.   85.0     390.0     16.0  36.0
# 18                  Lobster      aver.  100.0      92.0     18.0   1.0
# 19                Asparagus   6 spears   96.0      18.0      1.0   0.0
# 20              Cauliflower      1 cup  120.0      30.0      3.0   0.0
# 21              Blueberries      1 cup  250.0     245.0      1.0   0.0
# 22                   Grapes      1 cup  153.0      70.0      1.0   0.0
# 23              Whole-wheat    1 slice   23.0      55.0      2.0   1.0
# 24               Cornflakes      1 cup   25.0     110.0      2.0   0.0
# 25                  Oatmeal      1 cup  236.0     150.0      5.0   3.0
# 26              Sponge cake    1 slice   40.0     115.0      3.0   2.0
# 27                Doughnuts          1   33.0     135.0      2.0   7.0
#
#     Sat.Fat  Fiber  Carbs                          Category  taste_factor
# 0       3.0   1.00   13.0                    Dairy products           0.3
# 1      14.0   0.00    1.0                    Dairy products           0.3
# 2       3.0   0.00    0.0           Fats, Oils, Shortenings           0.1
# 3      25.0   0.00    0.0                     Meat, Poultry           0.5
# 4       1.0   0.00    0.0                     Fish, Seafood           0.5
# 5       0.0   0.90   10.0                    Vegetables A-E           0.5
# 6       0.0   0.50    2.0                    Vegetables F-P           0.5
# 7       0.0   1.00   18.0                        Fruits A-F           0.6
# 8      11.0   8.00   34.0                  Desserts, sweets           0.2
# 9      16.0   0.00   29.0                    Dairy products           0.3
# 10      7.0   0.00    0.0                     Meat, Poultry           0.5
# 11      0.0   0.00    0.0                     Fish, Seafood           0.5
# 12     12.0   1.80    6.0                        Fruits A-F           0.6
# 13      2.0   0.00   10.0                             Soups           0.5
# 14      6.0   0.20   44.0                  Desserts, sweets           0.2
# 15     15.0   0.00    0.0                     Meat, Poultry           0.5
# 16      7.0   0.00    1.0                     Meat, Poultry           0.5
# 17     35.0   0.00    0.0                     Meat, Poultry           0.5
# 18      0.0   0.00    0.0                     Fish, Seafood           0.5
# 19      0.0   0.50    3.0                    Vegetables A-E           0.5
# 20      0.0   1.00    6.0                    Vegetables A-E           0.5
# 21      0.0   2.00   65.0                        Fruits A-F           0.6
# 22      0.0   0.80   16.0                        Fruits G-P           0.6
# 23      0.0   0.31   11.0  Breads, cereals, fastfood,grains           0.4
# 24      0.0   0.10   25.0  Breads, cereals, fastfood,grains           0.4
# 25      2.0   4.60   26.0  Breads, cereals, fastfood,grains           0.4
# 26      2.0   0.00   22.0                  Desserts, sweets           0.2
# 27      4.0   0.00   17.0                  Desserts, sweets           0.2

# %%
def preference_factor(row):
    if row['Category'] == 'Dairy products':
        return 0.4
    if row['Category'] == 'Fats, Oils, Shortenings':
        return 0.3
    if row['Category'] == 'Meat, Poultry':
        return 0.8
    if row['Category'] == 'Fish, Seafood':
        return 0.6
    if row['Category'] == 'Vegetables A-E':
        return 0.4
    if row['Category'] == 'Vegetables F-P':
        return 0.4
    if row['Category'] == 'Vegetables R-Z':
        return 0.4
    if row['Category'] == 'Fruits A-F':
        return 0.6
    if row['Category'] == 'Fruits G-P':
        return 0.6
    if row['Category'] == 'Fruits R-Z':
        return 0.6
    if row['Category'] == 'Breads, cereals, fastfood,grains':
        return 0.5
    if row['Category'] == 'Soups':
        return 0.2
    if row['Category'] == 'Desserts, sweets':
        return 0.8
    if row['Category'] == 'Jams, Jellies':
        return 0.5
    if row['Category'] == 'Drinks,Alcohol, Beverages':
        return 0.6

# %%
df['preference_factor'] = df.apply(preference_factor, axis=1)
df
# Out:
#                        Food    Measure  Grams  Calories  Protein   Fat  \
# 0                skim. milk      1 cup  250.0     128.0     18.0   4.0
# 1   Eggs Scrambled or fried          2  128.0     220.0     13.0  16.0
# 2                 Olive oil        1T.   14.0     125.0      0.0  14.0
# 3                     Steak      3 oz.   85.0     330.0     20.0  27.0
# 4                    Salmon      3 oz.   85.0     120.0     17.0   5.0
# 5                   Carrots      1 cup  150.0      45.0      1.0   0.0
# 6                   Lettuce   1/4 head  100.0      14.0      1.0   0.0
# 7               Apples, raw      1 med  130.0      70.0      0.0   0.0
# 8               Pumpkin Pie    1 slice  130.0     265.0      5.0  12.0
# 9                 Ice cream      1 cup  188.0     300.0      6.0  18.0
# 10                  chicken      3 oz.   85.0     185.0     23.0   9.0
# 11                   Shrimp      3 oz.   85.0     110.0     23.0   1.0
# 12                  Avocado  1/2 large  108.0     185.0      2.0  18.0
# 13             chicken soup      1 cup  250.0      75.0      4.0   2.0
# 14           Milk chocolate  2-oz. bar   56.0     290.0      2.0   6.0
# 15                Hamburger      3 oz.   85.0     245.0     21.0  17.0
# 16                    Bacon   2 slices   16.0      95.0      4.0   8.0
# 17               Roast beef      3 oz.   85.0     390.0     16.0  36.0
# 18                  Lobster      aver.  100.0      92.0     18.0   1.0
# 19                Asparagus   6 spears   96.0      18.0      1.0   0.0
# 20              Cauliflower      1 cup  120.0      30.0      3.0   0.0
# 21              Blueberries      1 cup  250.0     245.0      1.0   0.0
# 22                   Grapes      1 cup  153.0      70.0      1.0   0.0
# 23              Whole-wheat    1 slice   23.0      55.0      2.0   1.0
# 24               Cornflakes      1 cup   25.0     110.0      2.0   0.0
# 25                  Oatmeal      1 cup  236.0     150.0      5.0   3.0
# 26              Sponge cake    1 slice   40.0     115.0      3.0   2.0
# 27                Doughnuts          1   33.0     135.0      2.0   7.0
#
#     Sat.Fat  Fiber  Carbs                          Category  taste_factor  \
# 0       3.0   1.00   13.0                    Dairy products           0.3
# 1      14.0   0.00    1.0                    Dairy products           0.3
# 2       3.0   0.00    0.0           Fats, Oils, Shortenings           0.1
# 3      25.0   0.00    0.0                     Meat, Poultry           0.5
# 4       1.0   0.00    0.0                     Fish, Seafood           0.5
# 5       0.0   0.90   10.0                    Vegetables A-E           0.5
# 6       0.0   0.50    2.0                    Vegetables F-P           0.5
# 7       0.0   1.00   18.0                        Fruits A-F           0.6
# 8      11.0   8.00   34.0                  Desserts, sweets           0.2
# 9      16.0   0.00   29.0                    Dairy products           0.3
# 10      7.0   0.00    0.0                     Meat, Poultry           0.5
# 11      0.0   0.00    0.0                     Fish, Seafood           0.5
# 12     12.0   1.80    6.0                        Fruits A-F           0.6
# 13      2.0   0.00   10.0                             Soups           0.5
# 14      6.0   0.20   44.0                  Desserts, sweets           0.2
# 15     15.0   0.00    0.0                     Meat, Poultry           0.5
# 16      7.0   0.00    1.0                     Meat, Poultry           0.5
# 17     35.0   0.00    0.0                     Meat, Poultry           0.5
# 18      0.0   0.00    0.0                     Fish, Seafood           0.5
# 19      0.0   0.50    3.0                    Vegetables A-E           0.5
# 20      0.0   1.00    6.0                    Vegetables A-E           0.5
# 21      0.0   2.00   65.0                        Fruits A-F           0.6
# 22      0.0   0.80   16.0                        Fruits G-P           0.6
# 23      0.0   0.31   11.0  Breads, cereals, fastfood,grains           0.4
# 24      0.0   0.10   25.0  Breads, cereals, fastfood,grains           0.4
# 25      2.0   4.60   26.0  Breads, cereals, fastfood,grains           0.4
# 26      2.0   0.00   22.0                  Desserts, sweets           0.2
# 27      4.0   0.00   17.0                  Desserts, sweets           0.2
#
#     preference_factor
# 0                 0.4
# 1                 0.4
# 2                 0.3
# 3                 0.8
# 4                 0.6
# 5                 0.4
# 6                 0.4
# 7                 0.6
# 8                 0.8
# 9                 0.4
# 10                0.8
# 11                0.6
# 12                0.6
# 13                0.2
# 14                0.8
# 15                0.8
# 16                0.8
# 17                0.8
# 18                0.6
# 19                0.4
# 20                0.4
# 21                0.6
# 22                0.6
# 23                0.5
# 24                0.5
# 25                0.5
# 26                0.8
# 27                0.8

# %%
import numpy as np
import scipy.optimize as opt

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def calculate_required_calories(weight=None, height=None, age=None, gender=None, activity_factor=None):
    # Mifflin -St Jeor Equations(MSJE)
    required_cal=2000 #default required 2000 calorie
    if weight is not None and height is not None and age is not None and gender is not None and activity_factor is not None:
        if gender=="male":
            required_cal=(10*weight+6.25*height-5*age+5)*activity_factor
        elif gender=="female":
            required_cal=(10*weight+6.25*height-5*age-161)*activity_factor
    return required_cal

# %%
from functools import partial
def diet_optimization(x, required_calories):
    # carb 45~60% 1carb=4cal
    diff_carb=abs(0.525*required_calories-4*np.dot(df['Carbs'].T,x))

    # protein 25~35% 1protein=4cal
    diff_protein=abs(0.3*required_calories-4*np.dot(df['Protein'].T,x))

    # fat 20~35% 1fat=9cal
    diff_fat=abs(0.225*required_calories-9*np.dot(df['Fat'].T,x))
    # calorie = np.sum(np.multiply(df['Calories'], x**2))
    # fat = np.sum(np.multiply(df['Fat'], x**2))*10
    # carbs = np.sum(np.multiply(df['Carbs'], x**2))*10
    return diff_carb+diff_protein+diff_fat


required_calories=calculate_required_calories(83,180,23,"male",1.3)

partial_diet_optimization = partial(diet_optimization, required_calories=required_calories)

# %%
def lower_calorie_constraint(x, required_calories):
    # gap between cal and required_cal should no more than 500
    calorie = np.dot(df['Calories'].T, x)
    return (calorie-required_calories+500)

def upper_calorie_constraint(x, required_calories):
    # gap between cal and required_cal should no more than 300
    calorie = np.dot(df['Calories'].T, x)
    return -(calorie-required_calories-300)

# def protein_constraint(x):
#     protein = np.sum(np.multiply(df['Protein'], x))
#     return (protein-100)

# def fiber_constraint(x):
#     fiber = np.sum(np.multiply(df['Fiber'], x))
#     return (fiber-15)

def taste_constraint(x):
    taste = np.sum(x**df['taste_factor'])
    return (taste-10)

def perference_constraint(x):
    preference = np.sum(np.multiply(df['preference_factor'], x))
    return (preference-10)

def volume_constraint(x):
    volume = np.sum(np.multiply(df['Grams'], x))
    return -(volume-2000)

# At most choose 10 items
def items_constraint_upper(x):
    return -(2*np.sum(sigmoid(100*x)-0.5)-9.9)
    

partial_lower_calorie_constraint = partial(lower_calorie_constraint, required_calories=required_calories)
partial_upper_calorie_constraint = partial(upper_calorie_constraint, required_calories=required_calories)

constraints = [{'type': 'ineq', 'fun': partial_lower_calorie_constraint},
               {'type': 'ineq', 'fun': partial_upper_calorie_constraint},
               {'type': 'ineq', 'fun': volume_constraint},
            #    {'type': 'ineq', 'fun': protein_constraint},
            #    {'type': 'ineq', 'fun': fiber_constraint},
               {'type': 'ineq', 'fun': taste_constraint},
               {'type': 'ineq', 'fun': perference_constraint},
               {'type': 'ineq', 'fun': items_constraint_upper}]

bounds = [(0,2)] * df.shape[0]

# %% [markdown]
# ### SLSQP (Sequential Least Square Programming)

# %%
x0 = np.zeros(df.shape[0])
options = {"disp": True, "maxiter": 5000}
result = opt.minimize(partial_diet_optimization, x0, method='SLSQP', bounds=bounds, 
                      constraints=constraints,options=options)
print(result.x)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 115.53034198102227
#             Iterations: 53
#             Function evaluations: 1543
#             Gradient evaluations: 51
# [2.94443886e-02 0.00000000e+00 4.07120335e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.00000000e+00
#  5.26684666e-01 1.14474763e-10 2.00000000e+00 2.00000000e+00
#  3.85567644e-10 0.00000000e+00 1.92075145e+00 0.00000000e+00
#  2.00000000e+00 0.00000000e+00 2.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.00000000e+00 7.12096070e-11]

# %%
calorie = np.sum(np.multiply(df['Calories'], result.x))
fat = np.sum(np.multiply(df['Fat'], result.x))
carbs = np.sum(np.multiply(df['Carbs'], result.x))
protein = np.sum(np.multiply(df['Protein'], result.x))
taste = np.sum(result.x**df['taste_factor'])
preference = np.sum(np.multiply(df['preference_factor'], result.x))
grams = (np.multiply(df['Grams'], result.x))

print(required_calories)
print(calorie)
print(protein)
print((result.x>0.01).sum())
print(taste)
print(preference)
df['diet'] = result.x
# Out:
# 2398.5
# 2524.358237751702
# 151.0049251321997
# 10
# 12.328840045350505
# 11.569726643683293

# %%
df['Number of Measure'] = result.x
filtered_df = df[df['Number of Measure'] >= 0.01][['Food', 'Measure', 'Number of Measure']]
pd.set_option('display.float_format', '{:.2f}'.format)
filtered_df
# Out:
#               Food    Measure  Number of Measure
# 0       skim. milk      1 cup               0.03
# 7      Apples, raw      1 med               2.00
# 8      Pumpkin Pie    1 slice               0.53
# 10         chicken      3 oz.               2.00
# 11          Shrimp      3 oz.               2.00
# 14  Milk chocolate  2-oz. bar               1.92
# 16           Bacon   2 slices               2.00
# 18         Lobster      aver.               2.00
# 21     Blueberries      1 cup               2.00
# 26     Sponge cake    1 slice               2.00

# %% [markdown]
# ### Trust - Contr Solver (Trust Region Constraint)

# %%
result_trust_constr = opt.minimize(partial_diet_optimization, x0, method='trust-constr', bounds=bounds, 
                                   constraints=constraints, options=options)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 1263, function evaluations: 41963, CG iterations: 2516, optimality: 9.86e-03, constraint violation: 0.00e+00, execution time: 2.3e+01 s.

# %%
# Display the results
print(result_trust_constr.x)

print("\nOptimization success:", result_trust_constr.success)
print("Objective function value at the solution (minimized difference):", result_trust_constr.fun)
print("Number of iterations performed:", result_trust_constr.nit)
print("Message:", result_trust_constr.message)
# Out:
# [1.64844483e+00 6.31653338e-06 6.27715506e-06 6.13878774e-06
#  6.57080595e-06 6.47152634e-06 7.24313592e-06 1.99984380e+00
#  1.99988507e+00 7.03475773e-06 6.68634587e-06 7.84974830e-06
#  6.28551605e-06 6.40233755e-06 7.43909929e-06 7.28997923e-06
#  4.21391586e-01 5.62315686e-06 1.99985643e+00 8.38740336e-06
#  1.96725200e+00 2.87632694e-02 7.62625305e-06 6.97678407e-06
#  1.03128683e-05 1.99963832e+00 1.99993848e+00 1.99989038e+00]
#
# Optimization success: True
# Objective function value at the solution (minimized difference): 487.60276299018057
# Number of iterations performed: 1263
# Message: `xtol` termination condition is satisfied.

# %%
calorie = np.sum(np.multiply(df['Calories'], result_trust_constr.x))
fat = np.sum(np.multiply(df['Fat'], result_trust_constr.x))
carbs = np.sum(np.multiply(df['Carbs'], result_trust_constr.x))
protein = np.sum(np.multiply(df['Protein'], result_trust_constr.x))
taste = np.sum(result.x**df['taste_factor'])
preference = np.sum(np.multiply(df['preference_factor'], result_trust_constr.x))
grams = (np.multiply(df['Grams'], result_trust_constr.x))

print(required_calories)
print(calorie)
print(protein)
print((result_trust_constr.x>0.01).sum())
print(taste)
print(preference)
# Out:
# 2398.5
# 1970.986549901526
# 103.28377502084574
# 10
# 12.328840045350505
# 10.000129933602617

# %%
df['Number of Measure'] = result_trust_constr.x
filtered_df = df[df['Number of Measure'] >= 0.01][['Food', 'Measure', 'Number of Measure']]
pd.set_option('display.float_format', '{:.2f}'.format)
filtered_df
# Out:
#            Food   Measure  Number of Measure
# 0    skim. milk     1 cup               1.65
# 7   Apples, raw     1 med               2.00
# 8   Pumpkin Pie   1 slice               2.00
# 16        Bacon  2 slices               0.42
# 18      Lobster     aver.               2.00
# 20  Cauliflower     1 cup               1.97
# 21  Blueberries     1 cup               0.03
# 25      Oatmeal     1 cup               2.00
# 26  Sponge cake   1 slice               2.00
# 27    Doughnuts         1               2.00

# %% [markdown]
# ### COBYLA (Constrained Optimization by Linear Approximation)

# %%
from scipy.optimize import minimize
options = {"maxiter": 5000}

cobyla_constraints = constraints + [{'type': 'ineq', 'fun': lambda x, lb=lb, ub=ub: x - lb, 'args': (lb,)} for lb, ub in bounds] + \
                                  [{'type': 'ineq', 'fun': lambda x, lb=lb, ub=ub: ub - x, 'args': (ub,)} for lb, ub in bounds]

# Perform the optimization using the 'COBYLA' method
result_cobyla = minimize(partial_diet_optimization, x0, method='COBYLA',
                         constraints=cobyla_constraints, options=options)

print(result_cobyla.x)

print("\nOptimization success:", result_cobyla.success)
print("Objective function value at the solution (minimized difference):", result_cobyla.fun)
# COBYLA does not provide a standardized 'nit' attribute for the number of iterations
print("Message:", result_cobyla.message)
# Out:
# [ 1.2298319   1.04415414  0.86497381  1.2463649   1.55102609  1.14405888
#   0.93525729  1.04726107  1.17257187 -0.02249469  1.13403482  0.94909645
#  -0.02249469  0.53085425  1.25064165  0.34917612  0.53756384  0.20441477
#  -0.02249469 -0.02249469 -0.02249469 -0.02167568 -0.02249469 -0.02249469
#  -0.02249469 -0.02249469  0.7834644   0.80899616]
#
# Optimization success: False
# Objective function value at the solution (minimized difference): 1274.4094284681896
# Message: Did not converge to a solution satisfying the constraints. See `maxcv` for magnitude of violation.

# %% [markdown]
# ### TNC (Truncated Newton Method)

# %%
result_tnc = opt.minimize(partial_diet_optimization, x0, method='TNC', bounds=bounds, 
                          constraints=constraints, options=options)

print("\nOptimization success:", result_tnc.success)
print("Objective function value at the solution (minimized difference):", result_tnc.fun)
print("Number of iterations performed:", result_tnc.nit)
print("Message:", result_tnc.message)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minimize.py:538: RuntimeWarning: Method TNC cannot handle constraints.
#   warn('Method %s cannot handle constraints.' % method,
# Optimization success: True
# Objective function value at the solution (minimized difference): 139.30013646068062
# Number of iterations performed: 17
# Message: Converged (|x_n-x_(n-1)| ~= 0)

# %%
calorie = np.sum(np.multiply(df['Calories'], result_tnc.x))
fat = np.sum(np.multiply(df['Fat'], result_tnc.x))
carbs = np.sum(np.multiply(df['Carbs'], result_tnc.x))
protein = np.sum(np.multiply(df['Protein'], result_tnc.x))
taste = np.sum(result.x**df['taste_factor'])
preference = np.sum(np.multiply(df['preference_factor'], result_tnc.x))
grams = (np.multiply(df['Grams'], result_tnc.x))

print('Required Calories: ',required_calories)
print('Calorie: ',calorie)
print('Protein: ', protein)
num_important_factor = (result_trust_constr.x>0.01).sum()
print('Number of Important factor: ', num_important_factor)
print('Taste Factor Sum: ', taste)
print('Preference Factor Sum: ', preference)
# Out:
# Required Calories:  2398.5
# Calorie:  2469.2049263700906
# Protein:  150.17261438742977
# Number of Important factor:  10
# Taste Factor Sum:  12.328840045350505
# Preference Factor Sum:  9.506825765840306

# %%
df['Number of Measure'] = result_tnc.x
filtered_df = df[df['Number of Measure'] != 0][['Food', 'Measure', 'Number of Measure']]
pd.set_option('display.float_format', '{:.8f}'.format)
filtered_df
# Out:
#                        Food    Measure  Number of Measure
# 0                skim. milk      1 cup         0.83535220
# 1   Eggs Scrambled or fried          2         0.18394690
# 4                    Salmon      3 oz.         0.54933887
# 5                   Carrots      1 cup         0.28755608
# 6                   Lettuce   1/4 head         0.09256212
# 7               Apples, raw      1 med         0.46370447
# 8               Pumpkin Pie    1 slice         0.93561314
# 9                 Ice cream      1 cup         0.80328822
# 10                  chicken      3 oz.         0.49828984
# 11                   Shrimp      3 oz.         2.00000000
# 13             chicken soup      1 cup         0.36105193
# 14           Milk chocolate  2-oz. bar         1.14512545
# 15                Hamburger      3 oz.         0.17722431
# 16                    Bacon   2 slices         0.08607231
# 17               Roast beef      3 oz.         0.01297307
# 18                  Lobster      aver.         2.00000000
# 19                Asparagus   6 spears         0.11214078
# 20              Cauliflower      1 cup         0.24387843
# 21              Blueberries      1 cup         1.68270989
# 22                   Grapes      1 cup         0.44674201
# 23              Whole-wheat    1 slice         0.43675343
# 24               Cornflakes      1 cup         0.70211923
# 25                  Oatmeal      1 cup         0.79696949
# 26              Sponge cake    1 slice         0.64010462
# 27                Doughnuts          1         0.45173135

# %% [markdown]
# ### L-BFGS-B (limited-memory BFGS algorithm)

# %%
options = {"disp": True, "maxiter": 5000}
result_lbfgsb = opt.minimize(partial_diet_optimization, x0, method='L-BFGS-B', bounds=bounds, 
                             options=options)

# %%
print("\nOptimization success:", result_lbfgsb.success)
print("Objective function value at the solution (minimized difference):", result_lbfgsb.fun)
print("Number of iterations performed:", result_lbfgsb.nit)
print("Message:", result_lbfgsb.message)
# Out:
# Optimization success: False
# Objective function value at the solution (minimized difference): 4.285023078409722e-05
# Number of iterations performed: 47
# Message: ABNORMAL_TERMINATION_IN_LNSRCH

# %% [markdown]
# ### Powell's Conjugate Direction Method

# %%
result_powell = opt.minimize(partial_diet_optimization, x0, method='Powell', 
                             options=options)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 5082

# %%
print('Required Calories: ',required_calories)
print('Calorie: ',calorie)
print('Protein: ', protein)
num_important_factor = (result_powell.x>0.01).sum()
print('Number of Important factor: ', num_important_factor)
print('Tate Factor Sum: ', taste)
print('Preference Factor Sum: ', preference)
df['diet'] = result_powell.x
print(result_powell.x)
# Out:
# Required Calories:  2398.5
# Calorie:  2469.2049263700906
# Protein:  150.17261438742977
# Number of Important factor:  7
# Tate Factor Sum:  12.328840045350505
# Preference Factor Sum:  9.506825765840306
# [ 1.49212772e+01 -2.47089462e-03  8.95650859e-06  1.11572045e-07
#  -5.16032925e+00  1.20734387e+01  4.70952813e-02  2.31456785e-05
#  -1.51335787e-08  1.43318964e+00 -9.39426692e-01 -1.33094164e-03
#   4.67687487e-01 -4.43220032e+00 -1.05302548e-03  5.29079234e-01
#  -1.01318837e-02 -1.50709584e-05  3.16796435e-01  3.27769116e-03
#   1.77500086e-06 -2.47551140e-10 -1.19404471e-11  1.00000000e-11
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -5.80857549e-08]

# %%
df['Number of Measure'] = result_powell.x
filtered_df = df[df['Number of Measure'] != 0][['Food', 'Measure', 'Number of Measure']]
filtered_df
# Out:
#                        Food    Measure  Number of Measure
# 0                skim. milk      1 cup       1.492128e+01
# 1   Eggs Scrambled or fried          2      -2.470895e-03
# 2                 Olive oil        1T.       8.956509e-06
# 3                     Steak      3 oz.       1.115720e-07
# 4                    Salmon      3 oz.      -5.160329e+00
# 5                   Carrots      1 cup       1.207344e+01
# 6                   Lettuce   1/4 head       4.709528e-02
# 7               Apples, raw      1 med       2.314568e-05
# 8               Pumpkin Pie    1 slice      -1.513358e-08
# 9                 Ice cream      1 cup       1.433190e+00
# 10                  chicken      3 oz.      -9.394267e-01
# 11                   Shrimp      3 oz.      -1.330942e-03
# 12                  Avocado  1/2 large       4.676875e-01
# 13             chicken soup      1 cup      -4.432200e+00
# 14           Milk chocolate  2-oz. bar      -1.053025e-03
# 15                Hamburger      3 oz.       5.290792e-01
# 16                    Bacon   2 slices      -1.013188e-02
# 17               Roast beef      3 oz.      -1.507096e-05
# 18                  Lobster      aver.       3.167964e-01
# 19                Asparagus   6 spears       3.277691e-03
# 20              Cauliflower      1 cup       1.775001e-06
# 21              Blueberries      1 cup      -2.475511e-10
# 22                   Grapes      1 cup      -1.194045e-11
# 23              Whole-wheat    1 slice       1.000000e-11
# 27                Doughnuts          1      -5.808575e-08
